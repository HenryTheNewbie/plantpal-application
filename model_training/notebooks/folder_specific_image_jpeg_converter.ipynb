# %%
import os
from PIL import Image

# Function to convert and rename images in each folder
def convert_and_rename_images_in_folder(input_dir, start_index=1):
    # Loop through all folders and files in the input directory
    for root, dirs, files in os.walk(input_dir):
        # Get the folder name for naming convention
        folder_name = os.path.basename(root)

        # Process each file in the folder
        for idx, filename in enumerate(files, start=start_index):
            if filename.endswith((".png", ".jpeg", ".bmp", ".gif", ".tiff", ".jfif", ".jpg")):  # Add other formats if needed
                img_path = os.path.join(root, filename)
                
                # Open the image
                img = Image.open(img_path)

                # Convert the image to RGB mode (necessary for JPEG format)
                rgb_img = img.convert("RGB")

                # Generate new filename using folder name and index starting from 1
                new_filename = f"{folder_name}_{str(idx).zfill(3)}.jpg"
                new_img_path = os.path.join(root, new_filename)

                # Save the image as .jpg with the new filename
                rgb_img.save(new_img_path, "JPEG")
                
                print(f"Converted {filename} to {new_filename}")

                # Delete the original file after conversion
                os.remove(img_path)
                print(f"Deleted original file: {filename}")

# Set your input directory
input_directory = "../data/train/strawberry_clover"  # Adjust this path as necessary

# Run the conversion and renaming, starting from index 1
convert_and_rename_images_in_folder(input_directory, start_index=1)
# Out:
# Converted trifolium_fragiferum_001.jpg to strawberry_clover_001.jpg
# Deleted original file: trifolium_fragiferum_001.jpg
# Converted trifolium_fragiferum_002.jpg to strawberry_clover_002.jpg
# Deleted original file: trifolium_fragiferum_002.jpg
# Converted trifolium_fragiferum_003.jpg to strawberry_clover_003.jpg
# Deleted original file: trifolium_fragiferum_003.jpg
# Converted trifolium_fragiferum_004.jpg to strawberry_clover_004.jpg
# Deleted original file: trifolium_fragiferum_004.jpg
# Converted trifolium_fragiferum_005.jpg to strawberry_clover_005.jpg
# Deleted original file: trifolium_fragiferum_005.jpg
# Converted trifolium_fragiferum_006.jpg to strawberry_clover_006.jpg
# Deleted original file: trifolium_fragiferum_006.jpg
# Converted trifolium_fragiferum_007.jpg to strawberry_clover_007.jpg
# Deleted original file: trifolium_fragiferum_007.jpg
# Converted trifolium_fragiferum_008.jpg to strawberry_clover_008.jpg
# Deleted original file: trifolium_fragiferum_008.jpg
# Converted trifolium_fragiferum_009.jpg to strawberry_clover_009.jpg
# Deleted original file: trifolium_fragiferum_009.jpg
# Converted trifolium_fragiferum_010.jpg to strawberry_clover_010.jpg
# Deleted original file: trifolium_fragiferum_010.jpg
# Converted trifolium_fragiferum_011.jpg to strawberry_clover_011.jpg
# Deleted original file: trifolium_fragiferum_011.jpg
# Converted trifolium_fragiferum_012.jpg to strawberry_clover_012.jpg
# Deleted original file: trifolium_fragiferum_012.jpg
# Converted trifolium_fragiferum_013.jpg to strawberry_clover_013.jpg
# Deleted original file: trifolium_fragiferum_013.jpg
# Converted trifolium_fragiferum_014.jpg to strawberry_clover_014.jpg
# Deleted original file: trifolium_fragiferum_014.jpg
# Converted trifolium_fragiferum_015.jpg to strawberry_clover_015.jpg
# Deleted original file: trifolium_fragiferum_015.jpg
# Converted trifolium_fragiferum_016.jpg to strawberry_clover_016.jpg
# Deleted original file: trifolium_fragiferum_016.jpg
# Converted trifolium_fragiferum_017.jpg to strawberry_clover_017.jpg
# Deleted original file: trifolium_fragiferum_017.jpg
# Converted trifolium_fragiferum_018.jpg to strawberry_clover_018.jpg
# Deleted original file: trifolium_fragiferum_018.jpg
# Converted trifolium_fragiferum_019.jpg to strawberry_clover_019.jpg
# Deleted original file: trifolium_fragiferum_019.jpg
# Converted trifolium_fragiferum_020.jpg to strawberry_clover_020.jpg
# Deleted original file: trifolium_fragiferum_020.jpg
