# %%
import os
from PIL import Image

# Function to convert and rename images in each folder
def convert_and_rename_images_in_folder(input_dir, start_index=1):
    # Loop through all folders and files in the input directory
    for root, dirs, files in os.walk(input_dir):
        # Get the folder name for naming convention
        folder_name = os.path.basename(root)

        # Process each file in the folder
        for idx, filename in enumerate(files, start=start_index):
            if filename.endswith((".png", ".jpeg", ".bmp", ".gif", ".tiff", ".jfif", ".jpg")):  # Add other formats if needed
                img_path = os.path.join(root, filename)
                
                # Open the image
                img = Image.open(img_path)

                # Convert the image to RGB mode (necessary for JPEG format)
                rgb_img = img.convert("RGB")

                # Generate new filename using folder name and index starting from 1
                new_filename = f"{folder_name}_{str(idx).zfill(3)}.jpg"
                new_img_path = os.path.join(root, new_filename)

                # Save the image as .jpg with the new filename
                rgb_img.save(new_img_path, "JPEG")
                
                print(f"Converted {filename} to {new_filename}")

                # Delete the original file after conversion
                os.remove(img_path)
                print(f"Deleted original file: {filename}")

# Set your input directory
input_directory = "../data/train/strawberry_clover"  # Adjust this path as necessary

# Run the conversion and renaming, starting from index 1
convert_and_rename_images_in_folder(input_directory, start_index=1)
# Out:
# Converted 002be58ba8ddbb1106a62266e808f04db067b11b.jpg to french_marigold_001.jpg
# Deleted original file: 002be58ba8ddbb1106a62266e808f04db067b11b.jpg
# Converted 00efe130b1985f24bb8fc2e8f71cbe0a3bf9c756.jpg to french_marigold_002.jpg
# Deleted original file: 00efe130b1985f24bb8fc2e8f71cbe0a3bf9c756.jpg
# Converted 01ba7af584d540d2532e434ea0e63fc92609c5d1.jpg to french_marigold_003.jpg
# Deleted original file: 01ba7af584d540d2532e434ea0e63fc92609c5d1.jpg
# Converted 03cab6100df9f273fb1170bcd2513a8bdd5be836.jpg to french_marigold_004.jpg
# Deleted original file: 03cab6100df9f273fb1170bcd2513a8bdd5be836.jpg
# Converted 0a2370267ace96746d107fee34cf6640af375bf0.jpg to french_marigold_005.jpg
# Deleted original file: 0a2370267ace96746d107fee34cf6640af375bf0.jpg
# Converted 0b54587e1ad74710b3cf536d33eec408a8d7efd3.jpg to french_marigold_006.jpg
# Deleted original file: 0b54587e1ad74710b3cf536d33eec408a8d7efd3.jpg
# Converted 0b927c6827f339ea89fa0326c38647be87602581.jpg to french_marigold_007.jpg
# Deleted original file: 0b927c6827f339ea89fa0326c38647be87602581.jpg
# Converted 0c77d3d4343fead8f0ade858fa6298c3468e32b3.jpg to french_marigold_008.jpg
# Deleted original file: 0c77d3d4343fead8f0ade858fa6298c3468e32b3.jpg
# Converted 0cec6afb74122795111356c472f491aaa945b8ad.jpg to french_marigold_009.jpg
# Deleted original file: 0cec6afb74122795111356c472f491aaa945b8ad.jpg
# Converted 0d7d7179fa343360e2587e5248621e7b1b7c22e5.jpg to french_marigold_010.jpg
# Deleted original file: 0d7d7179fa343360e2587e5248621e7b1b7c22e5.jpg
# Converted 0dcb78c5d7cc32a5bb227610ff52fbecdb23ed12.jpg to french_marigold_011.jpg
# Deleted original file: 0dcb78c5d7cc32a5bb227610ff52fbecdb23ed12.jpg
# Converted 0dd3b5e8a8e80ba0ffd1d378aa7dbae25b4645b4.jpg to french_marigold_012.jpg
# Deleted original file: 0dd3b5e8a8e80ba0ffd1d378aa7dbae25b4645b4.jpg
# Converted 0e4d9ae03e48ec2557d36024e694ded23c5e5301.jpg to french_marigold_013.jpg
